# %%
import numpy as np
import requests
import io
from PIL import Image
from IPython.display import display 

query = "tell me a joke"

appid = ""
url = "https://api.wolframalpha.com/v1/simple?"
params = {"appid": appid, "units": "metric", "i": query, "background":"transparent", "foreground":"black"}
r = requests.get(url, params)

image_data = r.content
image = Image.open(io.BytesIO(image_data))
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=540x345 at 0x7FE648E833A0>
